# %% [markdown]
# ### Importando as bibliotecas

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Puxando o df

# %%
try:
    notebook_path = os.path.dirname(__file__) # Para scripts .py
except NameError:
    notebook_path = os.getcwd() # Para notebooks .ipynb

# Sobe na árvore de diretórios até encontrar a pasta raiz do projeto ('Challenge_ClickBus')
# Ele faz isso procurando por um arquivo/pasta que sempre existe na raiz, como o '.gitignore'
project_root = notebook_path
while not os.path.exists(os.path.join(project_root, '.gitignore')):
    project_root = os.path.dirname(project_root)
    if project_root == os.path.dirname(project_root): # Evita loop infinito
        raise FileNotFoundError("Não foi possível encontrar a raiz do projeto. Verifique se o arquivo '.gitignore' existe.")


# Constrói o caminho para a pasta de dados a partir da raiz
PROCESSED = os.path.join(project_root, 'data', 'processed') + '/'

print(f"Pasta de dados encontrada em: {PROCESSED}")
# Out:
# Pasta de dados encontrada em: c:\Users\pedro\Documents\Estudos\FIAP\Challenges\ClickBus\data\processed/

# %%
caminho = os.path.join(PROCESSED, 'transacoes_preparado.parquet')
df = pd.read_parquet(caminho)
df
# Out:
#                                        nk_ota_localizer_id      fk_contact  \
# 0        bc02d5245bec63b30ff1102fa273fc03f58bc9cc3f674e...       Cliente 1
# 1        5432f12612dd5d749b3be880e779989cf63b5efa4bcc4e...       Cliente 2
# 2        fb3caed9b2f1b6016d45ccddb19095476e61a2c85faa8e...       Cliente 3
# 3        4dc44a6dd592b702feccb493d192210c86965aee684529...       Cliente 4
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# ...                                                    ...             ...
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741340  8bcfd696bb80f3433449c1442e4c6bab55d4bce9fe4311...  Cliente 126144
# 1741341  1924fa1e8daf5821b3d062ac29d1ba56c70a54b41a177b...  Cliente 130048
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 0          2018-12-26      15:33:35           Rodoviária 1
# 1          2018-12-05      15:07:57           Rodoviária 2
# 2          2018-12-21      18:41:54           Rodoviária 3
# 3          2018-12-06      14:01:38           Rodoviária 4
# 4          2021-02-23      20:08:25           Rodoviária 3
# ...               ...           ...                    ...
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741340    2019-08-01      10:06:37           Rodoviária 3
# 1741341    2019-01-18      10:28:42           Rodoviária 1
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 0                      Rodoviária 1                   0
# 1                      Rodoviária 2                   0
# 2                      Rodoviária 3                   0
# 3                      Rodoviária 4                   0
# 4                      Rodoviária 5                   0
# ...                             ...                 ...
# 1741339               Rodoviária 18                   0
# 1741340              Rodoviária 406                   0
# 1741341               Rodoviária 80                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 1741339                        0
# 1741340                        0
# 1741341                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 0        8527a891e224136950ff32ca212b45bc93f69fbb801c3b...
# 1        36ebe205bcdfc499a25e6923f4450fa8d48196ceb4fa0c...
# 2        ec2e990b934dde55cb87300629cedfc21b15cd28bbcf77...
# 3        5f9c4ab08cac7457e9111a30e4664920607ea2c115a143...
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# ...                                                    ...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741340  ec2e990b934dde55cb87300629cedfc21b15cd28bbcf77...
# 1741341  c17edaae86e4016a583e098582f6dbf3eccade8ef83747...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  total_tickets_quantity_success
# 0                               1        89.09                               1
# 1                               1       155.97                               1
# 2                               1       121.99                               1
# 3                               1        55.22                               1
# 4                               1        45.31                               1
# ...                           ...          ...                             ...
# 1741339                         1       156.00                               1
# 1741340                         1       106.93                               2
# 1741341                         1        92.77                               1
# 1741342                         1       294.99                               1
# 1741343                         1       158.95                               1
#
# [1741337 rows x 12 columns]

# %% [markdown]
# ### Pegando o range de data

# %%
data_max = df['date_purchase'].max()
data_min = df['date_purchase'].min()

print(f"Data range: {data_min} -> {data_max}")
# Out:
# Data range: 2013-09-12 00:00:00 -> 2024-04-01 00:00:00

# %% [markdown]
# ### Qtd de vendas em cada ano

# %%
df['ano'] = df['date_purchase'].dt.year
df.groupby('ano')['fk_contact'].count()
# Out:
# ano
# 2013       341
# 2014     15182
# 2015     29651
# 2016     54618
# 2017     81354
# 2018    100277
# 2019    180935
# 2020    145669
# 2021    262649
# 2022    380073
# 2023    383163
# 2024    107425
# Name: fk_contact, dtype: int64

# %% [markdown]
# ### Receita gerada em cada ano

# %%
df.groupby('ano')['gmv_success'].sum().round(2)
# Out:
# ano
# 2013       42239.96
# 2014     2174842.43
# 2015     4479928.20
# 2016     8159603.11
# 2017    12746278.85
# 2018    15573402.84
# 2019    28893918.48
# 2020    21221801.83
# 2021    39339358.54
# 2022    63527848.61
# 2023    65351074.62
# 2024    19011906.55
# Name: gmv_success, dtype: float64

# %%
anos_desejados = [2021, 2022, 2023, 2024]
df_filtrado = df[df['ano'].isin(anos_desejados)]

df_filtrado.shape
# Out:
# (1133310, 13)

# %% [markdown]
# ### 2021 -> 2024 existe a maioria das vendas do df, então vamos pegar apenas essa maior parte do df

# %%
df = df[df['date_purchase'] >= '2021-01-01']
df
# Out:
#                                        nk_ota_localizer_id      fk_contact  \
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# 5        948356b25b90c0c87c147cead27483c481edda1dacc4c8...       Cliente 6
# 6        2ee9d0978acb5e113d0b3f846ab3f88c5a426321da8f87...       Cliente 7
# 9        929cd361c225ec5d3510e14e8582fdcc61a24383cdb7a7...      Cliente 10
# 10       f08c3f551a19f1ce13525825dbf0d0ce9c3492da92bbb2...      Cliente 11
# ...                                                    ...             ...
# 1741337  52a39652c7b3db7eedbba20c16b4e68df6f514bec1ad79...  Cliente 133072
# 1741338  655038f142aea0104f73671352b3304617b8d19801495a...  Cliente 131770
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 4          2021-02-23      20:08:25           Rodoviária 3
# 5          2021-02-11      22:25:15           Rodoviária 5
# 6          2021-02-19      19:11:40           Rodoviária 6
# 9          2021-07-02      11:41:19           Rodoviária 8
# 10         2022-07-14      10:16:52           Rodoviária 9
# ...               ...           ...                    ...
# 1741337    2023-04-21      13:24:41           Rodoviária 1
# 1741338    2023-04-08      10:49:02           Rodoviária 6
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 4                      Rodoviária 5                   0
# 5                      Rodoviária 6                   0
# 6                      Rodoviária 7                   0
# 9                     Rodoviária 10                   0
# 10                    Rodoviária 11                   0
# ...                             ...                 ...
# 1741337               Rodoviária 80                   0
# 1741338               Rodoviária 18                   0
# 1741339               Rodoviária 18                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 4                              0
# 5                              0
# 6                              0
# 9                              0
# 10                             0
# ...                          ...
# 1741337                        0
# 1741338                        0
# 1741339                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# 5        1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
# 6        1d0ebea552eb43d0b1e1561f6de8ae92e3de7f1abec523...
# 9        c6f3ac57944a531490cd39902d0f777715fd005efac9a3...
# 10       96061e92f58e4bdcdee73df36183fe3ac64747c81c26f6...
# ...                                                    ...
# 1741337  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741338  f32828acecb4282c87eaa554d2e1db74e418cd68458430...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  \
# 4                               1        45.31
# 5                               1       154.20
# 6                               1       188.99
# 9                               1        61.55
# 10                              1        55.46
# ...                           ...          ...
# 1741337                         1       135.23
# 1741338                         1       183.92
# 1741339                         1       156.00
# 1741342                         1       294.99
# 1741343                         1       158.95
#
#          total_tickets_quantity_success   ano
# 4                                     1  2021
# 5                                     1  2021
# 6                                     1  2021
# 9                                     1  2021
# 10                                    1  2022
# ...                                 ...   ...
# 1741337                               1  2023
# 1741338                               1  2023
# 1741339                               1  2023
# 1741342                               1  2023
# 1741343                               1  2023
#
# [1133310 rows x 13 columns]

# %% [markdown]
# ### Volume financeiro no período

# %%
vlm_financeiro = df['gmv_success'].sum()
vlm_financeiro = round(vlm_financeiro, 2)
print(f"Volume financeiro: R${vlm_financeiro}")
# Out:
# Volume financeiro: R$187230188.32

# %% [markdown]
# ### Criando coluna de qtd de compras de cada cliente

# %%
df['qtd_compras'] = df['fk_contact'].map(df['fk_contact'].value_counts())
df
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11972\2873861594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['qtd_compras'] = df['fk_contact'].map(df['fk_contact'].value_counts())
#                                        nk_ota_localizer_id      fk_contact  \
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# 5        948356b25b90c0c87c147cead27483c481edda1dacc4c8...       Cliente 6
# 6        2ee9d0978acb5e113d0b3f846ab3f88c5a426321da8f87...       Cliente 7
# 9        929cd361c225ec5d3510e14e8582fdcc61a24383cdb7a7...      Cliente 10
# 10       f08c3f551a19f1ce13525825dbf0d0ce9c3492da92bbb2...      Cliente 11
# ...                                                    ...             ...
# 1741337  52a39652c7b3db7eedbba20c16b4e68df6f514bec1ad79...  Cliente 133072
# 1741338  655038f142aea0104f73671352b3304617b8d19801495a...  Cliente 131770
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 4          2021-02-23      20:08:25           Rodoviária 3
# 5          2021-02-11      22:25:15           Rodoviária 5
# 6          2021-02-19      19:11:40           Rodoviária 6
# 9          2021-07-02      11:41:19           Rodoviária 8
# 10         2022-07-14      10:16:52           Rodoviária 9
# ...               ...           ...                    ...
# 1741337    2023-04-21      13:24:41           Rodoviária 1
# 1741338    2023-04-08      10:49:02           Rodoviária 6
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 4                      Rodoviária 5                   0
# 5                      Rodoviária 6                   0
# 6                      Rodoviária 7                   0
# 9                     Rodoviária 10                   0
# 10                    Rodoviária 11                   0
# ...                             ...                 ...
# 1741337               Rodoviária 80                   0
# 1741338               Rodoviária 18                   0
# 1741339               Rodoviária 18                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 4                              0
# 5                              0
# 6                              0
# 9                              0
# 10                             0
# ...                          ...
# 1741337                        0
# 1741338                        0
# 1741339                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# 5        1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
# 6        1d0ebea552eb43d0b1e1561f6de8ae92e3de7f1abec523...
# 9        c6f3ac57944a531490cd39902d0f777715fd005efac9a3...
# 10       96061e92f58e4bdcdee73df36183fe3ac64747c81c26f6...
# ...                                                    ...
# 1741337  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741338  f32828acecb4282c87eaa554d2e1db74e418cd68458430...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  \
# 4                               1        45.31
# 5                               1       154.20
# 6                               1       188.99
# 9                               1        61.55
# 10                              1        55.46
# ...                           ...          ...
# 1741337                         1       135.23
# 1741338                         1       183.92
# 1741339                         1       156.00
# 1741342                         1       294.99
# 1741343                         1       158.95
#
#          total_tickets_quantity_success   ano  qtd_compras
# 4                                     1  2021            2
# 5                                     1  2021            3
# 6                                     1  2021            5
# 9                                     1  2021            8
# 10                                    1  2022           16
# ...                                 ...   ...          ...
# 1741337                               1  2023            2
# 1741338                               1  2023           14
# 1741339                               1  2023           59
# 1741342                               1  2023           59
# 1741343                               1  2023           13
#
# [1133310 rows x 14 columns]

# %%
df['total_gasto'] = df.groupby('fk_contact')['gmv_success'].transform('sum')
df['total_gasto'] = df['total_gasto'].round(2)
df
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11972\1675898690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_gasto'] = df.groupby('fk_contact')['gmv_success'].transform('sum')
# C:\Users\pedro\AppData\Local\Temp\ipykernel_11972\1675898690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_gasto'] = df['total_gasto'].round(2)
#                                        nk_ota_localizer_id      fk_contact  \
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# 5        948356b25b90c0c87c147cead27483c481edda1dacc4c8...       Cliente 6
# 6        2ee9d0978acb5e113d0b3f846ab3f88c5a426321da8f87...       Cliente 7
# 9        929cd361c225ec5d3510e14e8582fdcc61a24383cdb7a7...      Cliente 10
# 10       f08c3f551a19f1ce13525825dbf0d0ce9c3492da92bbb2...      Cliente 11
# ...                                                    ...             ...
# 1741337  52a39652c7b3db7eedbba20c16b4e68df6f514bec1ad79...  Cliente 133072
# 1741338  655038f142aea0104f73671352b3304617b8d19801495a...  Cliente 131770
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 4          2021-02-23      20:08:25           Rodoviária 3
# 5          2021-02-11      22:25:15           Rodoviária 5
# 6          2021-02-19      19:11:40           Rodoviária 6
# 9          2021-07-02      11:41:19           Rodoviária 8
# 10         2022-07-14      10:16:52           Rodoviária 9
# ...               ...           ...                    ...
# 1741337    2023-04-21      13:24:41           Rodoviária 1
# 1741338    2023-04-08      10:49:02           Rodoviária 6
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 4                      Rodoviária 5                   0
# 5                      Rodoviária 6                   0
# 6                      Rodoviária 7                   0
# 9                     Rodoviária 10                   0
# 10                    Rodoviária 11                   0
# ...                             ...                 ...
# 1741337               Rodoviária 80                   0
# 1741338               Rodoviária 18                   0
# 1741339               Rodoviária 18                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 4                              0
# 5                              0
# 6                              0
# 9                              0
# 10                             0
# ...                          ...
# 1741337                        0
# 1741338                        0
# 1741339                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# 5        1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
# 6        1d0ebea552eb43d0b1e1561f6de8ae92e3de7f1abec523...
# 9        c6f3ac57944a531490cd39902d0f777715fd005efac9a3...
# 10       96061e92f58e4bdcdee73df36183fe3ac64747c81c26f6...
# ...                                                    ...
# 1741337  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741338  f32828acecb4282c87eaa554d2e1db74e418cd68458430...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  \
# 4                               1        45.31
# 5                               1       154.20
# 6                               1       188.99
# 9                               1        61.55
# 10                              1        55.46
# ...                           ...          ...
# 1741337                         1       135.23
# 1741338                         1       183.92
# 1741339                         1       156.00
# 1741342                         1       294.99
# 1741343                         1       158.95
#
#          total_tickets_quantity_success   ano  qtd_compras  total_gasto
# 4                                     1  2021            2        85.92
# 5                                     1  2021            3       576.64
# 6                                     1  2021            5       750.89
# 9                                     1  2021            8      1052.88
# 10                                    1  2022           16       787.83
# ...                                 ...   ...          ...          ...
# 1741337                               1  2023            2       262.99
# 1741338                               1  2023           14      1562.74
# 1741339                               1  2023           59     10370.55
# 1741342                               1  2023           59     10370.55
# 1741343                               1  2023           13      2690.66
#
# [1133310 rows x 15 columns]

# %% [markdown]
# ### Criando o df de clientes

# %%
df_clientes = df[['fk_contact', 'total_gasto', 'qtd_compras']].drop_duplicates(subset='fk_contact')
df_clientes
# Out:
#              fk_contact  total_gasto  qtd_compras
# 4             Cliente 5        85.92            2
# 5             Cliente 6       576.64            3
# 6             Cliente 7       750.89            5
# 9            Cliente 10      1052.88            8
# 10           Cliente 11       787.83           16
# ...                 ...          ...          ...
# 1741290  Cliente 581808       569.57            1
# 1741303  Cliente 581809        76.78            1
# 1741315  Cliente 581811        82.48            1
# 1741329  Cliente 581812       119.82            1
# 1741331  Cliente 581813       330.40            1
#
# [375590 rows x 3 columns]

# %% [markdown]
# ### Criando df vendas

# %%
df_vendas = df
df_vendas = df.drop(columns=['total_gasto', 'qtd_compras'])
df_vendas
# Out:
#                                        nk_ota_localizer_id      fk_contact  \
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# 5        948356b25b90c0c87c147cead27483c481edda1dacc4c8...       Cliente 6
# 6        2ee9d0978acb5e113d0b3f846ab3f88c5a426321da8f87...       Cliente 7
# 9        929cd361c225ec5d3510e14e8582fdcc61a24383cdb7a7...      Cliente 10
# 10       f08c3f551a19f1ce13525825dbf0d0ce9c3492da92bbb2...      Cliente 11
# ...                                                    ...             ...
# 1741337  52a39652c7b3db7eedbba20c16b4e68df6f514bec1ad79...  Cliente 133072
# 1741338  655038f142aea0104f73671352b3304617b8d19801495a...  Cliente 131770
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 4          2021-02-23      20:08:25           Rodoviária 3
# 5          2021-02-11      22:25:15           Rodoviária 5
# 6          2021-02-19      19:11:40           Rodoviária 6
# 9          2021-07-02      11:41:19           Rodoviária 8
# 10         2022-07-14      10:16:52           Rodoviária 9
# ...               ...           ...                    ...
# 1741337    2023-04-21      13:24:41           Rodoviária 1
# 1741338    2023-04-08      10:49:02           Rodoviária 6
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 4                      Rodoviária 5                   0
# 5                      Rodoviária 6                   0
# 6                      Rodoviária 7                   0
# 9                     Rodoviária 10                   0
# 10                    Rodoviária 11                   0
# ...                             ...                 ...
# 1741337               Rodoviária 80                   0
# 1741338               Rodoviária 18                   0
# 1741339               Rodoviária 18                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 4                              0
# 5                              0
# 6                              0
# 9                              0
# 10                             0
# ...                          ...
# 1741337                        0
# 1741338                        0
# 1741339                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# 5        1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
# 6        1d0ebea552eb43d0b1e1561f6de8ae92e3de7f1abec523...
# 9        c6f3ac57944a531490cd39902d0f777715fd005efac9a3...
# 10       96061e92f58e4bdcdee73df36183fe3ac64747c81c26f6...
# ...                                                    ...
# 1741337  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741338  f32828acecb4282c87eaa554d2e1db74e418cd68458430...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  \
# 4                               1        45.31
# 5                               1       154.20
# 6                               1       188.99
# 9                               1        61.55
# 10                              1        55.46
# ...                           ...          ...
# 1741337                         1       135.23
# 1741338                         1       183.92
# 1741339                         1       156.00
# 1741342                         1       294.99
# 1741343                         1       158.95
#
#          total_tickets_quantity_success   ano
# 4                                     1  2021
# 5                                     1  2021
# 6                                     1  2021
# 9                                     1  2021
# 10                                    1  2022
# ...                                 ...   ...
# 1741337                               1  2023
# 1741338                               1  2023
# 1741339                               1  2023
# 1741342                               1  2023
# 1741343                               1  2023
#
# [1133310 rows x 13 columns]

# %% [markdown]
# ### Separando em PF/PJ

# %%
df_vendas.query('total_tickets_quantity_success > 10')
# Out:
#                                        nk_ota_localizer_id      fk_contact  \
# 824700                               16  2023
# 832698                               12  2021
# 844292                               12  2024
# 851562                               12  2022
# 863594                               12  2021
# 864798                               12  2022
# 871924                               12  2021
# 916382                               12  2022
# 1255019                              12  2021
# 1501488                              12  2022
# 1575840                              12  2023
# 1670604                              16  2021

# %%
df_clientes['tp_pessoa'] = np.where(df_clientes['total_gasto'] >= 60000, 'PJ', 'PF')
df_clientes['tp_pessoa'].value_counts()
# Out:
# PF    375561
# PJ        29
# Name: tp_pessoa, dtype: int64

# %%
df_clientes
# Out:
#              fk_contact  total_gasto  qtd_compras tp_pessoa
# 4             Cliente 5        85.92            2        PF
# 5             Cliente 6       576.64            3        PF
# 6             Cliente 7       750.89            5        PF
# 9            Cliente 10      1052.88            8        PF
# 10           Cliente 11       787.83           16        PF
# ...                 ...          ...          ...       ...
# 1741290  Cliente 581808       569.57            1        PF
# 1741303  Cliente 581809        76.78            1        PF
# 1741315  Cliente 581811        82.48            1        PF
# 1741329  Cliente 581812       119.82            1        PF
# 1741331  Cliente 581813       330.40            1        PF
#
# [375590 rows x 4 columns]

# %% [markdown]
# ### Colocando a data da ultima compra do cliente

# %%
df_clientes['ultima_compra'] = df_clientes['fk_contact'].map(df_vendas.groupby('fk_contact')['date_purchase'].max())
df_clientes
# Out:
#              fk_contact  total_gasto  qtd_compras tp_pessoa ultima_compra
# 4             Cliente 5        85.92            2        PF    2021-02-27
# 5             Cliente 6       576.64            3        PF    2021-07-02
# 6             Cliente 7       750.89            5        PF    2021-09-03
# 9            Cliente 10      1052.88            8        PF    2022-02-15
# 10           Cliente 11       787.83           16        PF    2022-07-14
# ...                 ...          ...          ...       ...           ...
# 1741290  Cliente 581808       569.57            1        PF    2022-02-26
# 1741303  Cliente 581809        76.78            1        PF    2023-10-12
# 1741315  Cliente 581811        82.48            1        PF    2022-12-18
# 1741329  Cliente 581812       119.82            1        PF    2022-02-10
# 1741331  Cliente 581813       330.40            1        PF    2023-11-02
#
# [375590 rows x 5 columns]

# %% [markdown]
# ### Fazendo o RFM de PF

# %%
df_rfm_pf = df_clientes[df_clientes['tp_pessoa'] == 'PF'].copy()
df_rfm_pf['recency'] = (df_rfm_pf['ultima_compra'].max() - df_rfm_pf['ultima_compra']).dt.days
df_rfm_pf['frequency'] = df_rfm_pf['qtd_compras']
df_rfm_pf['monetary'] = df_rfm_pf['total_gasto']
df_rfm_pf = df_rfm_pf.drop(columns=['tp_pessoa','ultima_compra', 'qtd_compras', 'total_gasto'])
df_rfm_pf
# Out:
#              fk_contact  recency  frequency  monetary
# 4             Cliente 5     1129          2     85.92
# 5             Cliente 6     1004          3    576.64
# 6             Cliente 7      941          5    750.89
# 9            Cliente 10      776          8   1052.88
# 10           Cliente 11      627         16    787.83
# ...                 ...      ...        ...       ...
# 1741290  Cliente 581808      765          1    569.57
# 1741303  Cliente 581809      172          1     76.78
# 1741315  Cliente 581811      470          1     82.48
# 1741329  Cliente 581812      781          1    119.82
# 1741331  Cliente 581813      151          1    330.40
#
# [375561 rows x 4 columns]

# %%
scaler = StandardScaler()
amostra = df_rfm_pf.sample(n=10000, random_state=42)
X_amostra = scaler.fit_transform(amostra[['recency', 'frequency', 'monetary']])

# %%
best_score = -1
best_k = 0

for k in range(2,11):
    modelo = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=2048)
    labels = modelo.fit_predict(X_amostra)
    score = silhouette_score(X_amostra, labels)
    print(f"Silhouette Score para k={k}: {score:.4f}")
    if score > best_score:
        best_score = score
        best_k = k
    
print(f"Melhor k: {best_k} com Silhouette Score: {best_score:.4f}")
# Out:
# Silhouette Score para k=2: 0.4730
# Silhouette Score para k=3: 0.4951
# Silhouette Score para k=4: 0.5055
# Silhouette Score para k=5: 0.4406
# Silhouette Score para k=6: 0.4131
# Silhouette Score para k=7: 0.3352
# Silhouette Score para k=8: 0.3339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 modelo = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=2048)
#       6 labels = modelo.fit_predict(X_amostra)
# ----> 7 score = silhouette_score(X_amostra, labels)
#       8 print(f"Silhouette Score para k={k}: {score:.4f}")
#       9 if score > best_score:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\cluster\_unsupervised.py:139, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     137     else:
#     138         X, labels = X[indices], labels[indices]
# --> 139 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\cluster\_unsupervised.py:303, in silhouette_samples(X, labels, metric, **kwds)
#     299 kwds["metric"] = metric
#     300 reduce_func = functools.partial(
#     301     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     302 )
# --> 303 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     304 intra_clust_dists, inter_clust_dists = results
#     305 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\pairwise.py:2252, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2250 else:
#    2251     X_chunk = X[sl]
# -> 2252 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2253 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2254     metric, None
#    2255 ) is euclidean_distances:
#    2256     # zeroing diagonal, taking care of aliases of "euclidean",
#    2257     # i.e. "l2"
#    2258     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\pairwise.py:2480, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, ensure_all_finite, **kwds)
#    2477         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2478     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2480 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\pairwise.py:1973, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1970 X, Y, dtype = _return_float_dtype(X, Y)
#    1972 if effective_n_jobs(n_jobs) == 1:
# -> 1973     return func(X, Y, **kwds)
#    1975 # enforce a threading backend to prevent data communication overhead
#    1976 fd = delayed(_dist_wrapper)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\pairwise.py:388, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     382     if Y_norm_squared.shape != (1, Y.shape[0]):
#     383         raise ValueError(
#     384             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     385             f"Y_norm_squared of shape {original_shape}."
#     386         )
# --> 388 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\pairwise.py:429, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     426     distances += YY
#     428 xp_zero = xp.asarray(0, device=device_, dtype=distances.dtype)
# --> 429 distances = _modify_in_place_if_numpy(
#     430     xp, xp.maximum, distances, xp_zero, out=distances
#     431 )
#     433 # Ensure that distances between vectors and themselves are set to 0.0.
#     434 # This may not be the case due to floating point rounding errors.
#     435 if X is Y:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_array_api.py:1082, in _modify_in_place_if_numpy(xp, func, out, *args, **kwargs)
#    1080 def _modify_in_place_if_numpy(xp, func, *args, out=None, **kwargs):
#    1081     if _is_numpy_namespace(xp):
# -> 1082         func(*args, out=out, **kwargs)
#    1083     else:
#    1084         out = func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
X_full = scaler.transform(df_rfm_pf[['recency', 'frequency', 'monetary']])
modelo_final = MiniBatchKMeans(n_clusters=best_k, random_state=42, batch_size=2048)
df_rfm_pf['cluster'] = modelo_final.fit_predict(X_full)
df_rfm_pf
# Out:
#              fk_contact  recency  frequency  monetary  cluster
# 4             Cliente 5     1129          2     85.92        0
# 5             Cliente 6     1004          3    576.64        0
# 6             Cliente 7      941          5    750.89        0
# 9            Cliente 10      776          8   1052.88        3
# 10           Cliente 11      627         16    787.83        3
# ...                 ...      ...        ...       ...      ...
# 1741290  Cliente 581808      765          1    569.57        3
# 1741303  Cliente 581809      172          1     76.78        2
# 1741315  Cliente 581811      470          1     82.48        3
# 1741329  Cliente 581812      781          1    119.82        0
# 1741331  Cliente 581813      151          1    330.40        2
#
# [375561 rows x 5 columns]

# %%
df_rfm_pf.groupby('cluster')[['recency', 'frequency', 'monetary']].mean()
# Out:
#             recency  frequency     monetary
# cluster
# 0        950.592456   1.469174   238.348405
# 1        159.476562  25.057292  3830.507425
# 2        142.977191   3.071695   507.256880
# 3        576.767439   1.929193   337.585866

# %%
mapa_clusters = {
    0: 'Pessoa - Dormindo',
    1: 'Pessoa - Super Vip',
    2: 'Pessoa - Potencial',
    3: 'Pessoa - Quase dormindo'}

df_rfm_pf['cluster'] = df_rfm_pf['cluster'].map(mapa_clusters)
df_rfm_pf['cluster'].value_counts()
df_rfm_pf
# Out:
#              fk_contact  recency  frequency  monetary                  cluster
# 4             Cliente 5     1129          2     85.92        Pessoa - Dormindo
# 5             Cliente 6     1004          3    576.64        Pessoa - Dormindo
# 6             Cliente 7      941          5    750.89        Pessoa - Dormindo
# 9            Cliente 10      776          8   1052.88  Pessoa - Quase dormindo
# 10           Cliente 11      627         16    787.83  Pessoa - Quase dormindo
# ...                 ...      ...        ...       ...                      ...
# 1741290  Cliente 581808      765          1    569.57  Pessoa - Quase dormindo
# 1741303  Cliente 581809      172          1     76.78       Pessoa - Potencial
# 1741315  Cliente 581811      470          1     82.48  Pessoa - Quase dormindo
# 1741329  Cliente 581812      781          1    119.82        Pessoa - Dormindo
# 1741331  Cliente 581813      151          1    330.40       Pessoa - Potencial
#
# [375561 rows x 5 columns]

# %% [markdown]
# ### Fazendo RFM de PJ

# %%
df_clientes['grupo'] = df_clientes['fk_contact'].map(df_rfm_pf.set_index('fk_contact')['cluster'])
df_clientes['grupo'].value_counts()
# Out:
# Pessoa - Potencial         149898
# Pessoa - Quase dormindo    124479
# Pessoa - Dormindo           89664
# Pessoa - Super Vip          11520
# Name: grupo, dtype: int64

# %%
df_rfm_pj = df_clientes[df_clientes['tp_pessoa'] == 'PJ'].copy()
df_rfm_pj['recency'] = (df_rfm_pj['ultima_compra'].max() - df_rfm_pj['ultima_compra']).dt.days
df_rfm_pj['frequency'] = df_rfm_pj['qtd_compras']
df_rfm_pj['monetary'] = df_rfm_pj['total_gasto']
df_rfm_pj = df_rfm_pj.drop(columns=['tp_pessoa','ultima_compra', 'qtd_compras', 'total_gasto', 'grupo'])
df_rfm_pj
# Out:
#             fk_contact  recency  frequency   monetary
# 2175      Cliente 1585       10        305   68015.59
# 2438      Cliente 1790        6        137   78207.51
# 25166    Cliente 11759       34        747  190209.93
# 25192    Cliente 11783        1        433  133072.71
# 25222    Cliente 11810      468        303   94523.59
# 38293    Cliente 19174      161       1203  308986.47
# 52531    Cliente 27214      306        142  103602.41
# 76680    Cliente 41355      213        389  129975.48
# 102958   Cliente 56456      606        100   61899.42
# 102971   Cliente 56467      515        372  107178.88
# 102977   Cliente 56472      746        714   91090.92
# 115545   Cliente 63705      468        433   74237.49
# 129147   Cliente 71731      619        302   74657.80
# 130104   Cliente 72422       19         69   68869.11
# 153465   Cliente 82890        0       1043  454229.01
# 216591  Cliente 107660       24        658  193058.02
# 217105  Cliente 108016        3        933  139411.39
# 234660  Cliente 116723      217       1022  280698.56
# 255543  Cliente 127264       32        278  100274.57
# 281634  Cliente 139606       21        163   63374.33
# 317262  Cliente 159765        4        483  140668.58
# 369086  Cliente 183728        2        704  134529.65
# 386975  Cliente 191959      152        305   63408.04
# 520548  Cliente 242614      112        161   70968.75
# 520790  Cliente 241747        0        301  120613.79
# 553980  Cliente 252642       16        125   80410.87
# 576643  Cliente 264263        0        199   84428.71
# 576731  Cliente 264344       17        137   79212.56
# 709866  Cliente 316158       39        172   82514.29

# %%
scaler = StandardScaler()
x = scaler.fit_transform(df_rfm_pj[['recency', 'frequency', 'monetary']])

# %%
best_k = 0
best_score = -1

for k in range(2,11):
    modelo = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=2048)
    labels = modelo.fit_predict(x)
    score = silhouette_score(x, labels)
    print(f"Silhouette Score para k={k}: {score:.4f}")
    if score > best_score:
        best_score = score
        best_k = k
        
print(f"Melhor k: {best_k} com Silhouette Score: {best_score:.4f}")
# Out:
# Silhouette Score para k=2: 0.4743
# Silhouette Score para k=3: 0.5226
# Silhouette Score para k=4: 0.5281
# Silhouette Score para k=5: 0.4434
# Silhouette Score para k=6: 0.4768
# Silhouette Score para k=7: 0.4299
# Silhouette Score para k=8: 0.3994
# Silhouette Score para k=9: 0.3434
# Silhouette Score para k=10: 0.3578
# Melhor k: 4 com Silhouette Score: 0.5281

# %%
df_rfm_pj['cluster'] = modelo_final.fit_predict(x)
df_rfm_pj.groupby('cluster')[['recency', 'frequency', 'monetary']].mean()
# Out:
#             recency    frequency       monetary
# cluster
# 0        126.000000  1089.333333  347971.346667
# 1         49.000000   210.846154   83867.200000
# 2         11.333333   659.666667  155158.380000
# 3        532.571429   338.000000   86741.501429

# %%
mapa_niveis_pj = {
    0: "Empresa - VIP Consistente",
    1: "Empresa - Ativo Recente",
    2: "Empresa - Super Ativo",
    3: "Empresa - Dormindo"
}

df_rfm_pj['cluster'] = df_rfm_pj['cluster'].map(mapa_niveis_pj)

# %%
df_rfm_pj['cluster'].value_counts()
# Out:
# Empresa - Ativo Recente      13
# Empresa - Dormindo            7
# Empresa - Super Ativo         6
# Empresa - VIP Consistente     3
# Name: cluster, dtype: int64

# %% [markdown]
# ### Aplicando os GPs de PJ no df_cliente

# %%
df_clientes.loc[df_clientes['tp_pessoa'] == 'PJ', 'grupo'] = (
    df_clientes.loc[df_clientes['tp_pessoa'] == 'PJ', 'fk_contact']
    .map(df_rfm_pj.set_index('fk_contact')['cluster'])
)
df_clientes['grupo'].value_counts()
# Out:
# Pessoa - Potencial           149898
# Pessoa - Quase dormindo      124479
# Pessoa - Dormindo             89664
# Pessoa - Super Vip            11520
# Empresa - Ativo Recente          13
# Empresa - Dormindo                7
# Empresa - Super Ativo             6
# Empresa - VIP Consistente         3
# Name: grupo, dtype: int64

# %% [markdown]
# ### Descobrindo os endereços mais visitados

# %%
df_vendas['place_destination_departure'].value_counts().head(10)
# Out:
# Rodoviária 18     137967
# Rodoviária 17      82445
# Rodoviária 33      42839
# Rodoviária 9       38172
# Rodoviária 16      30853
# Rodoviária 42      27044
# Rodoviária 94      23235
# Rodoviária 91      15818
# Rodoviária 160     13452
# Rodoviária 69      12995
# Name: place_destination_departure, dtype: int64

# %%
df_cidades = df_vendas['place_origin_departure'].drop_duplicates()
df_cidades.shape
# Out:
# (2425,)

# %%
df_cidades.duplicated().sum()
# Out:
# 0

# %%
df_vendas['place_origin_departure'] = df_vendas['place_origin_departure']
df_vendas['place_origin_departure'].value_counts().head(20)
# Out:
# Rodoviária 1      158867
# Rodoviária 3       94468
# Rodoviária 6       46163
# Rodoviária 4       41660
# Rodoviária 10      35867
# Rodoviária 18      33754
# Rodoviária 29      24268
# Rodoviária 57      18384
# Rodoviária 55      17745
# Rodoviária 81      15843
# Rodoviária 107     15296
# Rodoviária 5       14241
# Rodoviária 64      13259
# Rodoviária 16      13016
# Rodoviária 30      12712
# Rodoviária 74      10353
# Rodoviária 83      10142
# Rodoviária 53       8985
# Rodoviária 168      8509
# Rodoviária 39       7772
# Name: place_origin_departure, dtype: int64

# %% [markdown]
# ### Gasto médio de cada cliente

# %%
df_clientes['ticket_medio'] = df_clientes['total_gasto'] / df_clientes['qtd_compras']
df_clientes['ticket_medio'] = df_clientes['ticket_medio'].round(2)
df_clientes
# Out:
#              fk_contact  total_gasto  qtd_compras tp_pessoa ultima_compra  \
# 4             Cliente 5        85.92            2        PF    2021-02-27
# 5             Cliente 6       576.64            3        PF    2021-07-02
# 6             Cliente 7       750.89            5        PF    2021-09-03
# 9            Cliente 10      1052.88            8        PF    2022-02-15
# 10           Cliente 11       787.83           16        PF    2022-07-14
# ...                 ...          ...          ...       ...           ...
# 1741290  Cliente 581808       569.57            1        PF    2022-02-26
# 1741303  Cliente 581809        76.78            1        PF    2023-10-12
# 1741315  Cliente 581811        82.48            1        PF    2022-12-18
# 1741329  Cliente 581812       119.82            1        PF    2022-02-10
# 1741331  Cliente 581813       330.40            1        PF    2023-11-02
#
#                            grupo  ticket_medio
# 4              Pessoa - Dormindo         42.96
# 5              Pessoa - Dormindo        192.21
# 6              Pessoa - Dormindo        150.18
# 9        Pessoa - Quase dormindo        131.61
# 10       Pessoa - Quase dormindo         49.24
# ...                          ...           ...
# 1741290  Pessoa - Quase dormindo        569.57
# 1741303       Pessoa - Potencial         76.78
# 1741315  Pessoa - Quase dormindo         82.48
# 1741329        Pessoa - Dormindo        119.82
# 1741331       Pessoa - Potencial        330.40
#
# [375590 rows x 7 columns]

# %% [markdown]
# ### Exportando DFs para CSV

# %%
CSV = os.getenv('CSV_PATH')
df_clientes.to_csv(f'{CSV}cliente.csv', index=False)

# %%
df_vendas.to_csv(f'{CSV}vendas.csv', index=False)

# %% [markdown]
# ### Guardando Cluster em uma Variavel

# %%
# Unifica os dataframes de pessoa física e jurídica
df_clusters_completo = pd.concat([df_rfm_pf, df_rfm_pj], axis=0)

# --- ALTERAÇÃO APLICADA AQUI ---
# Agrupa por cluster e calcula a média, mínimo e máximo para cada métrica RFM
df_clusters_agregado = df_clusters_completo.groupby('cluster').agg(
    recency_mean=('recency', 'mean'),
    recency_min=('recency', 'min'),
    recency_max=('recency', 'max'),
    frequency_mean=('frequency', 'mean'),
    frequency_min=('frequency', 'min'),
    frequency_max=('frequency', 'max'),
    monetary_mean=('monetary', 'mean'),
    monetary_min=('monetary', 'min'),
    monetary_max=('monetary', 'max')
).reset_index()

# Junta a contagem de clientes em cada cluster
qtd_clientes = df_clientes['grupo'].value_counts().reset_index()
qtd_clientes.columns = ['cluster', 'Qtd']
df_clusters_final = pd.merge(df_clusters_agregado, qtd_clientes, on='cluster')


# Salva o resultado final nos caminhos desejados
CAMINHO_WEBHOOK = os.path.join(project_root,'Desafios', 'data', 'webhook') + '/'
df_clusters_final.to_csv(f'{CAMINHO_WEBHOOK}cluster.csv', index=False)
df_clusters_final.to_csv(f'{CSV}cluster.csv', index=False)

print("Arquivo de clusters gerado com sucesso, incluindo métricas de Média, Mínimo e Máximo.")
display(df_clusters_final)
# Out:
# Arquivo de clusters gerado com sucesso, incluindo métricas de Média, Mínimo e Máximo.
#                      cluster  recency_mean  recency_min  recency_max  \
# 0    Empresa - Ativo Recente     49.000000            0          213
# 1         Empresa - Dormindo    532.571429          306          746
# 2      Empresa - Super Ativo     11.333333            1           34
# 3  Empresa - VIP Consistente    126.000000            0          217
# 4          Pessoa - Dormindo    950.592456          775         1186
# 5         Pessoa - Potencial    142.977191            0          502
# 6    Pessoa - Quase dormindo    576.767439          359          874
# 7         Pessoa - Super Vip    159.476562            0         1180
#
#    frequency_mean  frequency_min  frequency_max  monetary_mean  monetary_min  \
# 0      210.846154             69            389   83867.200000      63374.33
# 1      338.000000            100            714   86741.501429      61899.42
# 2      659.666667            433            933  155158.380000     133072.71
# 3     1089.333333           1022           1203  347971.346667     280698.56
# 4        1.469174              1             21     238.348405          4.19
# 5        3.071695              1             22     507.256880          5.00
# 6        1.929193              1             22     337.585866          5.00
# 7       25.057292              1            437    3830.507425        333.66
#
#    monetary_max     Qtd
# 0     129975.48      13
# 1     107178.88       7
# 2     193058.02       6
# 3     454229.01       3
# 4       4400.94   89664
# 5       3809.98  149898
# 6       3946.68  124479
# 7      58158.68   11520

# %% [markdown]
# ### Visualizando as empresas_onibus

# %%
df_vendas
# Out:
#                                        nk_ota_localizer_id      fk_contact  \
# 4        aa34ed7fd0a6b405df2df1bf9f8d68e6df9b9a868a6181...       Cliente 5
# 5        948356b25b90c0c87c147cead27483c481edda1dacc4c8...       Cliente 6
# 6        2ee9d0978acb5e113d0b3f846ab3f88c5a426321da8f87...       Cliente 7
# 9        929cd361c225ec5d3510e14e8582fdcc61a24383cdb7a7...      Cliente 10
# 10       f08c3f551a19f1ce13525825dbf0d0ce9c3492da92bbb2...      Cliente 11
# ...                                                    ...             ...
# 1741337  52a39652c7b3db7eedbba20c16b4e68df6f514bec1ad79...  Cliente 133072
# 1741338  655038f142aea0104f73671352b3304617b8d19801495a...  Cliente 131770
# 1741339  4e4f5fcded3e8b6915e05c6b9b504ec6830f723a831f68...  Cliente 133024
# 1741342  18b75368642c6c347fd00f56cd98322bb6d920b6a07545...  Cliente 133024
# 1741343  113a96cafbc0fc70ab6cfba8bc017c57e720366265820c...  Cliente 130059
#
#         date_purchase time_purchase place_origin_departure  \
# 4          2021-02-23      20:08:25           Rodoviária 3
# 5          2021-02-11      22:25:15           Rodoviária 5
# 6          2021-02-19      19:11:40           Rodoviária 6
# 9          2021-07-02      11:41:19           Rodoviária 8
# 10         2022-07-14      10:16:52           Rodoviária 9
# ...               ...           ...                    ...
# 1741337    2023-04-21      13:24:41           Rodoviária 1
# 1741338    2023-04-08      10:49:02           Rodoviária 6
# 1741339    2023-12-29      19:47:12           Rodoviária 6
# 1741342    2023-01-08      23:57:55           Rodoviária 6
# 1741343    2023-01-14      21:40:39           Rodoviária 6
#
#         place_destination_departure place_origin_return  \
# 4                      Rodoviária 5                   0
# 5                      Rodoviária 6                   0
# 6                      Rodoviária 7                   0
# 9                     Rodoviária 10                   0
# 10                    Rodoviária 11                   0
# ...                             ...                 ...
# 1741337               Rodoviária 80                   0
# 1741338               Rodoviária 18                   0
# 1741339               Rodoviária 18                   0
# 1741342               Rodoviária 18                   0
# 1741343               Rodoviária 18                   0
#
#         place_destination_return  \
# 4                              0
# 5                              0
# 6                              0
# 9                              0
# 10                             0
# ...                          ...
# 1741337                        0
# 1741338                        0
# 1741339                        0
# 1741342                        0
# 1741343                        0
#
#                               fk_departure_ota_bus_company  \
# 4        48449a14a4ff7d79bb7a1b6f3d488eba397c36ef25634c...
# 5        1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
# 6        1d0ebea552eb43d0b1e1561f6de8ae92e3de7f1abec523...
# 9        c6f3ac57944a531490cd39902d0f777715fd005efac9a3...
# 10       96061e92f58e4bdcdee73df36183fe3ac64747c81c26f6...
# ...                                                    ...
# 1741337  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741338  f32828acecb4282c87eaa554d2e1db74e418cd68458430...
# 1741339  3068430da9e4b7a674184035643d9e19af3dc7483e31cc...
# 1741342  35135aaa6cc23891b40cb3f378c53a17a1127210ce60e1...
# 1741343  1dfacb2ea5a03e0a915999e03b5a56196f1b1664d2f768...
#
#         fk_return_ota_bus_company  gmv_success  \
# 4                               1        45.31
# 5                               1       154.20
# 6                               1       188.99
# 9                               1        61.55
# 10                              1        55.46
# ...                           ...          ...
# 1741337                         1       135.23
# 1741338                         1       183.92
# 1741339                         1       156.00
# 1741342                         1       294.99
# 1741343                         1       158.95
#
#          total_tickets_quantity_success   ano
# 4                                     1  2021
# 5                                     1  2021
# 6                                     1  2021
# 9                                     1  2021
# 10                                    1  2022
# ...                                 ...   ...
# 1741337                               1  2023
# 1741338                               1  2023
# 1741339                               1  2023
# 1741342                               1  2023
# 1741343                               1  2023
#
# [1133310 rows x 13 columns]
